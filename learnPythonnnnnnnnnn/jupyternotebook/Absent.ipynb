# %%
def my_function():
  print("Hello from Mars")
my_function()
# Out:
# Hello from Mars

# %%
def my_function():
  print("Hello from Mars")

my_function()
my_function()
my_function()
# Out:
# Hello from Mars
# Hello from Mars
# Hello from Mars
