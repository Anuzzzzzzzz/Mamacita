# %%
# import pandas as pd
# import numpy as np
# df=pd.read_csv('ecommerce_sales_data.csv')
# df

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("engrmazeem/e-commerce-sales-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/danuzz/.cache/kagglehub/datasets/engrmazeem/e-commerce-sales-data/versions/1

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(f'{path}/ecommerce_sales_data.csv')
df
# Out:
#                                    Order ID Product Name       Category  \
# 0      261e3740-c0e9-42b1-bf87-881ac950fa3a     audience  Home & Garden
# 1      0b332b34-46dc-4eaf-a808-fec7e97ffbc6         such       Clothing
# 2      432e0b36-724d-4521-85ae-f66db8af8105         read       Clothing
# 3      ca20fb08-5c65-43b8-9577-3fa49913f93b        skill    Electronics
# 4      1dce189c-8c60-455f-a6f2-69bb2cb71539         cold    Electronics
# ...                                     ...          ...            ...
# 99995  67e1224d-86a1-411c-a880-69c3786a15e9          lot           Toys
# 99996  9ad2bf4d-9453-472a-ae50-9d6d2cf8e5e4       animal       Clothing
# 99997  43c58940-e1ab-4e8a-8cea-f02811904c06       simply    Electronics
# 99998  97b93cc6-93e1-487b-94d3-8b02e6f74038         lose       Clothing
# 99999  192e6ac4-2d97-4055-bec9-d0175f768ec3      nothing  Home & Garden
#
#         Price  Quantity  Total Sales                           Customer ID  \
# 0      766.85         4      3067.40  81af1248-afff-46ee-a091-81cf33d0d957
# 1      331.42         4      1325.68  f3f3f4ac-7ad0-4362-9134-383096d16ac8
# 2      708.10        10      7081.00  c4fc4269-3c1d-4b6b-ad23-d437c328d63f
# 3      774.09         2      1548.18  578e2d1a-d92a-449d-8eeb-b704110b2975
# 4      397.22         1       397.22  dc6ed196-0874-46bd-bbb9-c5534f619349
# ...       ...       ...          ...                                   ...
# 99995  777.82         2      1555.64  a38aebb9-d3b4-468b-a999-e6d26d62635f
# 99996  473.23         1       473.23  4fa8f362-4897-4633-995d-ec5acffbb4d7
# 99997  591.40         8      4731.20  190b3b11-217d-43ed-b6d2-aa55be036c85
# 99998  490.93         1       490.93  60e350b2-601a-401c-a8f7-f45e827a6594
# 99999  938.06         8      7504.48  a060dacf-962a-464c-a5c5-a5de55014e3b
#
#        Customer Age Customer Gender Purchase Date Purchase Time
# 0                39            Male    25/05/2024       6:28:14
# 1                21            Male    04/05/2024      19:37:36
# 2                27          Female    07/05/2024      17:54:42
# 3                51          Female    23/05/2024      22:31:43
# 4                45          Female    15/03/2024       3:08:25
# ...             ...             ...           ...           ...
# 99995            32            Male    01/05/2024       4:49:40
# 99996            48          Female    21/05/2024       9:13:18
# 99997            41            Male    25/03/2024      13:34:07
# 99998            56          Female    01/06/2024       3:09:28
# 99999            46            Male    30/05/2024      20:12:20
#
# [100000 rows x 11 columns]

# %%
df.describe()
# Out:
#                Price       Quantity    Total Sales  Customer Age
# count  100000.000000  100000.000000  100000.000000  100000.00000
# mean      550.550363       5.493160    3027.926702      44.01757
# std       260.558267       2.882013    2274.140853      15.30850
# min       100.050000       1.000000     100.050000      18.00000
# 25%       323.967500       3.000000    1153.515000      31.00000
# 50%       551.100000       5.000000    2433.885000      44.00000
# 75%       777.125000       8.000000    4443.337500      57.00000
# max       999.990000      10.000000    9999.400000      70.00000

# %%
df.info
# Out:
# <bound method DataFrame.info of                                    Order ID Product Name       Category  \
# 0      261e3740-c0e9-42b1-bf87-881ac950fa3a     audience  Home & Garden
# 1      0b332b34-46dc-4eaf-a808-fec7e97ffbc6         such       Clothing
# 2      432e0b36-724d-4521-85ae-f66db8af8105         read       Clothing
# 3      ca20fb08-5c65-43b8-9577-3fa49913f93b        skill    Electronics
# 4      1dce189c-8c60-455f-a6f2-69bb2cb71539         cold    Electronics
# ...                                     ...          ...            ...
# 99995  67e1224d-86a1-411c-a880-69c3786a15e9          lot           Toys
# 99996  9ad2bf4d-9453-472a-ae50-9d6d2cf8e5e4       animal       Clothing
# 99997  43c58940-e1ab-4e8a-8cea-f02811904c06       simply    Electronics
# 99998  97b93cc6-93e1-487b-94d3-8b02e6f74038         lose       Clothing
# 99999  192e6ac4-2d97-4055-bec9-d0175f768ec3      nothing  Home & Garden
#
#         Price  Quantity  Total Sales                           Customer ID  \
# 0      766.85         4      3067.40  81af1248-afff-46ee-a091-81cf33d0d957
# 1      331.42         4      1325.68  f3f3f4ac-7ad0-4362-9134-383096d16ac8
# 2      708.10        10      7081.00  c4fc4269-3c1d-4b6b-ad23-d437c328d63f
# 3      774.09         2      1548.18  578e2d1a-d92a-449d-8eeb-b704110b2975
# 4      397.22         1       397.22  dc6ed196-0874-46bd-bbb9-c5534f619349
# ...       ...       ...          ...                                   ...
# 99995  777.82         2      1555.64  a38aebb9-d3b4-468b-a999-e6d26d62635f
# 99996  473.23         1       473.23  4fa8f362-4897-4633-995d-ec5acffbb4d7
# 99997  591.40         8      4731.20  190b3b11-217d-43ed-b6d2-aa55be036c85
# 99998  490.93         1       490.93  60e350b2-601a-401c-a8f7-f45e827a6594
# 99999  938.06         8      7504.48  a060dacf-962a-464c-a5c5-a5de55014e3b
#
#        Customer Age Customer Gender Purchase Date Purchase Time
# 0                39            Male    25/05/2024       6:28:14
# 1                21            Male    04/05/2024      19:37:36
# 2                27          Female    07/05/2024      17:54:42
# 3                51          Female    23/05/2024      22:31:43
# 4                45          Female    15/03/2024       3:08:25
# ...             ...             ...           ...           ...
# 99995            32            Male    01/05/2024       4:49:40
# 99996            48          Female    21/05/2024       9:13:18
# 99997            41            Male    25/03/2024      13:34:07
# 99998            56          Female    01/06/2024       3:09:28
# 99999            46            Male    30/05/2024      20:12:20
#
# [100000 rows x 11 columns]>

# %%
df.isnull()
# Out:
#        Order ID  Product Name  Category  Price  Quantity  Total Sales  \
# 0         False         False     False  False     False        False
# 1         False         False     False  False     False        False
# 2         False         False     False  False     False        False
# 3         False         False     False  False     False        False
# 4         False         False     False  False     False        False
# ...         ...           ...       ...    ...       ...          ...
# 99995     False         False     False  False     False        False
# 99996     False         False     False  False     False        False
# 99997     False         False     False  False     False        False
# 99998     False         False     False  False     False        False
# 99999     False         False     False  False     False        False
#
#        Customer ID  Customer Age  Customer Gender  Purchase Date  \
# 0            False         False            False          False
# 1            False         False            False          False
# 2            False         False            False          False
# 3            False         False            False          False
# 4            False         False            False          False
# ...            ...           ...              ...            ...
# 99995        False         False            False          False
# 99996        False         False            False          False
# 99997        False         False            False          False
# 99998        False         False            False          False
# 99999        False         False            False          False
#
#        Purchase Time
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 99995          False
# 99996          False
# 99997          False
# 99998          False
# 99999          False
#
# [100000 rows x 11 columns]

# %%
df.count()
# Out:
# Order ID           100000
# Product Name       100000
# Category           100000
# Price              100000
# Quantity           100000
# Total Sales        100000
# Customer ID        100000
# Customer Age       100000
# Customer Gender    100000
# Purchase Date      100000
# Purchase Time      100000
# dtype: int64

# %%
df.dtypes
# Out:
# Order ID            object
# Product Name        object
# Category            object
# Price              float64
# Quantity             int64
# Total Sales        float64
# Customer ID         object
# Customer Age         int64
# Customer Gender     object
# Purchase Date       object
# Purchase Time       object
# dtype: object

# %%
df['Customer Gender'].value_counts()
# Out:
# Customer Gender
# Female    50090
# Male      49910
# Name: count, dtype: int64

# %%
# df.iloc[0]: Select the first row by position

print(df.iloc[0])
# Out:
# Order ID           261e3740-c0e9-42b1-bf87-881ac950fa3a
# Product Name                                   audience
# Category                                  Home & Garden
# Price                                            766.85
# Quantity                                              4
# Total Sales                                      3067.4
# Customer ID        81af1248-afff-46ee-a091-81cf33d0d957
# Customer Age                                         39
# Customer Gender                                    Male
# Purchase Date                                25/05/2024
# Purchase Time                                   6:28:14
# Name: 0, dtype: object

# %%
# df.loc[...]: Select specific columns
subset = df.loc[0:5, ['Order ID', 'Category', 'Price', 'Customer Gender']]
display(subset)
# Out:
#                                Order ID       Category   Price Customer Gender
# 0  261e3740-c0e9-42b1-bf87-881ac950fa3a  Home & Garden  766.85            Male
# 1  0b332b34-46dc-4eaf-a808-fec7e97ffbc6       Clothing  331.42            Male
# 2  432e0b36-724d-4521-85ae-f66db8af8105       Clothing  708.10          Female
# 3  ca20fb08-5c65-43b8-9577-3fa49913f93b    Electronics  774.09          Female
# 4  1dce189c-8c60-455f-a6f2-69bb2cb71539    Electronics  397.22          Female
# 5  ebb310bc-aeba-4c74-a6ad-38823e86d950  Home & Garden  857.68          Female

# %%
# Sort by Category (A-Z) then Amount (High to Low)
sorted_df = df.sort_values(by=['Category', 'Price'], ascending=[True, False])

# %%
# Sort by Category (A-Z) then Amount (High to Low)
sorted_df = df.sort_values(by=['Category', 'Price'], ascending=[True, False])

display(sorted_df[['Category', 'Price', 'Purchase Date']].head())
# Out:
#       Category   Price Purchase Date
# 31951    Books  999.96    12/03/2024
# 75341    Books  999.95    20/02/2024
# 62400    Books  999.86    08/02/2024
# 92262    Books  999.77    08/03/2024
# 42855    Books  999.73    31/01/2024

# %%
# ## 2. Transformation (Sorting & Filtering)
# **Concepts:** `sort_values`, `query`, boolean masking.

# %%
# Task: Find the Top 5 costliest orders in 'Western Dress' category
# Syntax: df.sort_values(['col1', 'col2'], ascending=[True, False])

# %%
sorted_df=df.sort_values(by=['Purchase Date','Total Sales'],ascending=[True,False])
display(sorted_df[['Purchase Date','Total Sales','Product Name']].head())
sorted_df
# Out:
#       Purchase Date  Total Sales Product Name
# 50887    01/01/2024       9999.4        every
# 36087    01/01/2024       9736.4          yes
# 31222    01/01/2024       9671.9       system
# 47096    01/01/2024       9624.3    professor
# 6571     01/01/2024       9514.6       behind
#                                    Order ID Product Name       Category  \
# 50887  c53426a0-b6ec-4bbb-a59c-9d46eaae5092        every  Home & Garden
# 36087  9d7e1a5b-d1ac-4439-a1d3-ddda7a07a8f2          yes       Clothing
# 31222  1277c5eb-7361-453a-b5ad-4fbf153f5480       system  Home & Garden
# 47096  4a1363da-1257-4ff2-b508-08cbb7d29ea7    professor  Home & Garden
# 6571   ad03bed6-7990-4d25-9b27-7d9ba0a2d80e       behind           Toys
# ...                                     ...          ...            ...
# 28030  b4ac6683-37d7-44d9-88d8-1cb466e7a81a         long          Books
# 14186  758d404c-b65c-4f79-8c7f-173ddfa327a1        young           Toys
# 74813  53dcf0b3-3a2a-41df-b405-f2f558a889cd        agent          Books
# 42141  93018098-c3c9-452d-b138-e73c4a5f7b82       indeed  Home & Garden
# 12435  62a7ac35-4e2f-4d80-a960-2c45915f744d        spend          Books
#
#         Price  Quantity  Total Sales                           Customer ID  \
# 50887  999.94        10      9999.40  59fedcf1-59a3-427b-87c1-12d109a689d6
# 36087  973.64        10      9736.40  fd4444d5-4ac9-44e9-8dce-f208f0415c3b
# 31222  967.19        10      9671.90  0084c222-55d4-4e50-a099-4f63119efa87
# 47096  962.43        10      9624.30  c2eaa0b2-d13e-4ed0-b7ce-989b1968b1de
# 6571   951.46        10      9514.60  75aaca99-f056-419a-b20d-f24eaeee4ab2
# ...       ...       ...          ...                                   ...
# 28030  166.40         1       166.40  f5b62a29-5f7a-4a07-9904-e52e79534edd
# 14186  160.35         1       160.35  dfce6ce5-021f-474b-affa-8dc5d1641a22
# 74813  157.57         1       157.57  75ddfe01-cfed-420f-9ecc-ff801eee87e7
# 42141  135.06         1       135.06  43bacc6e-1caf-475c-9ced-7f71400b9767
# 12435  101.80         1       101.80  e37ce25c-ac48-4585-925b-2b23457dc23f
#
#        Customer Age Customer Gender Purchase Date Purchase Time
# 50887            36          Female    01/01/2024       5:43:39
# 36087            57          Female    01/01/2024       8:03:53
# 31222            40            Male    01/01/2024      17:46:36
# 47096            48            Male    01/01/2024      14:35:05
# 6571             61          Female    01/01/2024      12:07:35
# ...             ...             ...           ...           ...
# 28030            42            Male    31/05/2024       1:59:57
# 14186            48            Male    31/05/2024      20:50:34
# 74813            38            Male    31/05/2024      19:28:11
# 42141            21            Male    31/05/2024      13:32:17
# 12435            35          Female    31/05/2024       8:52:35
#
# [100000 rows x 11 columns]

# %%
df['Category'].value_counts()
# Out:
# Category
# Clothing         20144
# Home & Garden    20074
# Books            20027
# Electronics      19899
# Toys             19856
# Name: count, dtype: int64

# %% [markdown]
# Filtering:

# %%
### Filtering

# Method 1: Boolean Masking
mask = (df['Price'] > 990) & (df['Category'] == 'Electronics')
print(f"High Value of Electronics Orders (Mask): {len(df[mask])}")
# Out:
# High Value of Electronics Orders (Mask): 222

# %%
mask = (df['Customer Gender'] == 'Female') & (df['Total Sales'] > 900)
print(f"Count (Mask): {len(df[mask])}")
# Out:
# Count (Mask): 40817

# %%
#method 2: Query syntax

filtering_query = df.query('Price>990 & Category == "Electronics"')
print(f"High Value of Electronics Orders (Query): {len(filtering_query)}")
display(filtering_query[['Order ID', 'Price']].head(3))
# Out:
# High Value of Electronics Orders (Query): 222
#                                   Order ID   Price
# 333   5d474461-c5bc-4594-9f0d-6b51f9243707  994.65
# 913   fa533e7e-be71-46af-95c9-e0cacd6d3149  997.38
# 1826  ffa97bf4-4b10-44fd-b7cb-99829f714a98  990.84

# %%
query_df = df.query("`Customer Gender` == 'Female' and `Customer Age` < 20")
print(f"Count (Query): {len(query_df)}")

display(query_df.head(3))
# Out:
# Count (Query): 1905
#                                  Order ID Product Name     Category   Price  \
# 44   feab344a-9ea5-4de8-b815-25447455ac05   individual  Electronics  407.42
# 138  12bddc6d-e0b3-4b23-9c17-690569b59124    professor        Books  773.78
# 171  088eff69-217b-44e0-a8b9-3b4a7b5dc0f0        young         Toys  414.53
#
#      Quantity  Total Sales                           Customer ID  \
# 44          5      2037.10  91574b39-bf3b-40b0-8ba5-92fda828953d
# 138         1       773.78  5b8011d5-5af0-4748-9e32-e53c20cc09af
# 171         4      1658.12  1c595846-1cc6-4b89-8b22-98bcad5531b7
#
#      Customer Age Customer Gender Purchase Date Purchase Time
# 44             19          Female    22/05/2024      22:26:24
# 138            18          Female    12/03/2024      22:49:06
# 171            18          Female    03/04/2024      14:45:25

# %%
def classify_age(age):
    if age <30:
        return 'Young'
    elif age <50:
        return 'Middle-aged'
    else:
        return 'Senior'
    #apply to customer age column
df['Age Group'] = df['Customer Age'].apply(classify_age)
df[['Customer Age', 'Age Group']].head(10)

#verify
print(df['Age Group'].value_counts())
display(df[['Customer Age', 'Age Group']].head(10))
# Out:
# Age Group
# Senior         39540
# Middle-aged    37797
# Young          22663
# Name: count, dtype: int64
#    Customer Age    Age Group
# 0            39  Middle-aged
# 1            21        Young
# 2            27        Young
# 3            51       Senior
# 4            45  Middle-aged
# 5            33  Middle-aged
# 6            58       Senior
# 7            59       Senior
# 8            43  Middle-aged
# 9            57       Senior

# %%
import matplotlib.pyplot as plt
age=df['Age Group'].value_counts()
print(age)
df.plot()
# Out:
# Age Group
# Senior         39540
# Middle-aged    37797
# Young          22663
# Name: count, dtype: int64
# <Axes: >

# %%
pip install matplotlib
# Out:
#   Cell In[63], line 2
#     pip install matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/danuzz/Documents/notebooks/.venv/lib/python3.14/site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/danuzz/Documents/notebooks/.venv/lib/python3.14/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/danuzz/Documents/notebooks/.venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/danuzz/Documents/notebooks/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
# Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp314-cp314-macosx_10_15_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.9-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Using cached pillow-12.1.0-cp314-cp314-macosx_11_0_arm64.whl (4.7 MB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#grouping and aggregating
grouped_df = df.groupby('Category').agg({
    'Total Sales': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Number of Orders'})
display(grouped_df)
# Out:
#                Total Sales  Number of Orders
# Category
# Books          60820086.17             20027
# Clothing       61071489.36             20144
# Electronics    59955937.12             19899
# Home & Garden  60670371.57             20074
# Toys           60274785.96             19856

# %%
# Group by Category, Sum the Total Sales
cat_performance = df.groupby('Category')['Total Sales'].sum().reset_index()

# Sort for better view
cat_performance = cat_performance.sort_values('Total Sales', ascending=False)

# Format as currency string for readability
pd.options.display.float_format = '${:,.2f}'.format

display(cat_performance)
# Out:
#         Category    Total Sales
# 1       Clothing $61,071,489.36
# 0          Books $60,820,086.17
# 3  Home & Garden $60,670,371.57
# 4           Toys $60,274,785.96
# 2    Electronics $59,955,937.12

# %%
aged_df = df.groupby('Age Group').agg({
    'Total Sales': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Number of Orders'})
display(aged_df)
# Out:
#                 Total Sales  Number of Orders
# Age Group
# Middle-aged $114,407,193.78             37797
# Senior      $120,348,041.26             39540
# Young        $68,037,435.14             22663

# %%
cat_performance = df.groupby(['Category']).agg({
    'Total Sales': ['sum', 'mean', 'max'],
    'Order ID': 'count'
})
display(cat_performance)
# Out:
#                  Total Sales                     Order ID
#                          sum      mean       max    count
# Category
# Books         $60,820,086.17 $3,036.90 $9,993.10    20027
# Clothing      $61,071,489.36 $3,031.75 $9,998.70    20144
# Electronics   $59,955,937.12 $3,013.01 $9,996.20    19899
# Home & Garden $60,670,371.57 $3,022.34 $9,999.40    20074
# Toys          $60,274,785.96 $3,035.60 $9,999.10    19856

# %%
# ### B. Advanced Aggregation
# **Task:** Analyze `Total Sales` by `Age Group`.
#
# We want: Min, Max, Average, and Count of sales.
age_group_performance = df.groupby('Age Group').agg({
    'Total Sales': ['min', 'max', 'mean'],
    'Order ID': 'count'
})
display(age_group_performance)
# Out:
#             Total Sales                     Order ID
#                     min       max      mean    count
# Age Group
# Middle-aged     $100.05 $9,999.40 $3,026.89    37797
# Senior          $100.07 $9,998.70 $3,043.70    39540
# Young           $100.14 $9,996.20 $3,002.14    22663

# %%
total_sales = df['Total Sales'].sum()
print(f"Total Sales: ${total_sales:,.2f}")
# Out:
# Total Sales: $302,792,670.18

# %%
cust=df.groupby('Customer ID')['Total Sales'].sum().reset_index()
cust=cust.sort_values('Total Sales',ascending=False)
display(cust)
# Out:
#                                 Customer ID  Total Sales
# 35552  59fedcf1-59a3-427b-87c1-12d109a689d6    $9,999.40
# 20365  337db941-81be-4bd7-8003-e867c6e28a5b    $9,999.10
# 2228   05940bfc-3072-43dd-959a-f961a9f4cbf8    $9,998.70
# 11737  1d9b1f44-e605-42ad-ad9c-a117f87a4d13    $9,998.30
# 52097  84762f6f-61a1-46b9-b651-d8e310849f6a    $9,997.60
# ...                                     ...          ...
# 71821  b7308920-d45d-4e88-a586-c11d913ebf0c      $100.37
# 75100  bfa125df-3f46-4669-824b-4d2e8b3c7195      $100.28
# 91168  e9290eee-dcf4-4170-a602-3f0871dec3d6      $100.14
# 53226  87595e96-f8d4-4353-8b17-ecbe87bdd2b9      $100.07
# 21365  35fb2836-0129-41e8-91fd-7d764aebd75b      $100.05
#
# [100000 rows x 2 columns]
