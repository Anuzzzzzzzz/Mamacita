# %%
import math

print(math.pi)      
print(math.sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
from random import randint, choice


print(randint(1, 10))  
options = ['apple', 'banana', 'cherry']
print(choice(options))
# Out:
# 10
# apple
